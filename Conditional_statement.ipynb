# %% [markdown]
# <a href="https://colab.research.google.com/github/krishjoshi777/PythonLabKrish/blob/main/Conditional_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment-6
#
# ## Title - Study of conditional statements in Python
#
# ## Name : Krish Joshi
# ## PRN : 25070123064
# ## Batch : A3

# %%
#1a. Check whether a number is positive, negative
#1b. Check whether a number is positive, negative, or zero


num = int(input("Enter a number: "))
#1(a)
if num >= 0:
  print("The number is positive")
else:
  print("The number is negative")

#1(b)
if num > 0:
  print("The number is positive")
elif num == 0:
  print("The number is zero")
else:
  print("The number is negative")
# Out:
# Enter a number: 12
# The number is positive
# The number is positive

# %%
#2. Check whether a number is odd or even

num = int(input("Enter a number: "))
if num % 2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number: 123
# The number is odd

# %%
#3. Check which is the greater number.

num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
if num1 > num2:
  print("1st number is greater than the 2nd number.")
elif num1 < num2:
  print("2nd number is greater than the 1st number.")
else:
  print("Both the numbers are equal.1")
# Out:
# Enter a number: 10
# Enter a number: 10
# Both the numbers are equal.

# %%
#4. Find the largest of three numbers

num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
num3 = int(input("Enter a number: "))
if num1 > num2 and num1 > num3:
  print("The first number is the greatest.")
elif num2 > num1 and num2 > num3:
  print("The second number is the greatest.")
elif num3 > num1 and num3 > num2:
  print("The third number is the greatest.")
else:
  print("All the numbers are equal.")
# Out:
# Enter a number: 112
# Enter a number: 112
# Enter a number: 112
# All the numbers are equal.

# %%
#5. Get input from user for 5 subjects and find average
#Calculate grade using if-elif-else

Mathematics = int(input("Enter marks in Mathematics: "))
History = int(input("Enter marks in History: "))
English = int(input("Enter marks in English: "))
Physics = int(input("Enter marks in Physics: "))
Psychology = int(input("Enter marks in Psychology: "))

avg_marks = (Mathematics + History + English + Physics + Psychology) / 5

if avg_marks >= 90:
  print("Grade: A")
elif 80 <= avg_marks < 90:
  print("Grade: B")
elif 70 <= avg_marks < 80:
  print("Grade: C")
elif 60 <= avg_marks < 70:
  print("Grade: D")
else:
  print("Pass")
# Out:
# Enter marks in Mathematics: 55
# Enter marks in History: 88
# Enter marks in English: 90
# Enter marks in Physics: 72
# Enter marks in Psychology: 80
# Grade: C

# %%
# Check whether a year is a leap year
year=int(input("Enter a year: "))
if (year % 400==0) or (year % 4==0 and year % 100!=0):
  print("The year is a leap year")
else:
  print("The year is not a leap year")
# Out:
# Enter a year: 2024
# The year is a leap year

# %%
date=input("Enter a date in {dd/mm/yyyy} format: ")
dd,mm,yy=date.split('/')
dd=int(dd)
mm=int(mm)
yy=int(yy)
if(mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12): max1=31
elif(mm==4 or mm==6 or mm==9 or mm==11): max2=30
elif(yy%4==0 and yy%100!=0 or yy%400==0): max3=29
else:
# Out:
# Enter a date in {dd/mm/yyyy} format: 02/09/2007

# %%
''' Problem Statement:
Write a Python program to calculate the gross salary of an employee based on basic salary.

If basic <= 10000: HRA = 20%, DA= 80%
If basic <= 20000: HRA = 25%, DA= 90%
Otherwise: HRA = 30%, DA = 95%'''
basic=float(input("Enter basic salary: "))
if basic <= 10000:
  HRA=(basic*0.2)
  DA=(basic*0.8)
elif basic <= 20000:
  HRA=(basic*0.25)
  DA=(basic*0.9)
else:
  HRA=(basic*0.3)
  DA=(basic*0.95)
print("Final salary: ", basic+HRA+DA)
# Out:
# Enter basic salary: 5600
# Final salary:  11200.0

# %%
''' Write a Python Program to calculate income tax based on annual income'''
income=int(input("Enter annual income: "))
taxable= income - 250000
if taxable >= taxable and taxable <= 500000:
  tax=taxable*0.05
  print("Tax: ", tax)
elif taxable > 500000 and taxable <= 1000000:
  tax=taxable*0.1
  print("Tax: ", tax)
else:
  tax=taxable*0.3
  print("Tax: ", tax)
